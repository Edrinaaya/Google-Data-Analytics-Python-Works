# %% [markdown]
# <a href="https://colab.research.google.com/github/Edrinaaya/Google-Data-Analytics-Python-Works/blob/main/Python_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print to the console
print("Hello, world!")
# Out:
# Hello, world!

# %%
# print to the console
print(22)
# Out:
# 22

# %%
# Simple Arithmetic
(5 + 4) / 3
# Out:
# 3.0

# %%
# Assign Variables
country = "Brazil"
age = "30"

# %%
print(country)
print(age)
# Out:
# Brazil
# 30

# %%
# Evaluation
# Double single equals signs are used to check equivalency
10**3 == 1000
# Out:
# True

# %%
# Evaluation
## A single equals sign is reserved for assigning statements/variables.
10 * 3 == 40
# Out:
# False

# %%
10 * 3 == age
# Out:
# False

# %%
# A single equals sign is reserved for assignment statements.
if int (age) >= 18:
  print('adult')
else:
  print('minor')
# Out:
# adult

# %%
# Loop
for number in [1, 2, 3, 4, 5]:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list = (3, 6, 9)
for y in my_list:
    print(y/3)
# Out:
# 1.0
# 2.0
# 3.0

# %%
# Function Definition and Call
def is_adult(age):
  if age >= 18:
      print("adult")
  else:
      print("minor")

# %%
is_adult(14)
# Out:
# minor

# %%
# # Use the built-in sorted() function.
new_list = [20, 25, 10, 5]

sorted(new_list)
# Out:
# [5, 10, 20, 25]
